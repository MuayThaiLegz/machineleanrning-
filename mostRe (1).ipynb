# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder

import tensorflow as tf
from tensorflow import keras
import seaborn as sns
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_classif 
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score 
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate


from sklearn.preprocessing import OneHotEncoder
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn import feature_selection
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import f_classif
#import shap

gpu_devices = tf.config.experimental.list_physical_devices('GPU')

if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
    
    
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)



Shutdown_Physiologic = pd.read_csv("Shutdown_Physiologic.csv").drop('Unnamed: 0', axis=1).set_index(['case_id','phenotype'])

cat_encoder = OneHotEncoder(sparse=False)

pheno_type_cat = Shutdown_Physiologic[['pheno']]
pheno_type_cat_1hot = cat_encoder.fit_transform(pheno_type_cat)
Shutdown_Physiologic['pheno'] = pheno_type_cat_1hot

#scaled_Shutdown_Physiologic = (Shutdown_Physiologic - Shutdown_Physiologic.mean()) / Shutdown_Physiologic.std()
sklr = StandardScaler()

y = Shutdown_Physiologic['pheno']
y = y.astype(int)

X_to_drop = Shutdown_Physiologic.drop("pheno", axis=1)
temp_X = sklr.fit_transform(X_to_drop)
X = pd.DataFrame(temp_X,columns=X_to_drop.columns, index = X_to_drop.index)

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, stratify=y)

feats_list = []
# Out:
# Using CPU

# %%
feats_list.append(['abQ_IGHG1',
 'pQ1_SERPINC1',
 'pQ2_KLKB1',
 'pQ2_SERPINF2_a',
 'pQ2_SERPINF2_b',
 'pQ5_SERPINF2',
 'pQ6_SERPINA10',
 'pQ6_SERPINA5',
 'pQ7_ATRN'])

feats_list.append(['abQ_IGJ',
 'pQ1_APOC1',
 'pQ2_APOE',
 'pQ2_F2_a',
 'pQ3_CPB2',
 'pQ5_A2M',
 'pQ5_CFB',
 'pQ5_FABP1',
 'pQ6_C1R',
 'pQ6_LGALS3BP',
 'pQ6_SERPINA10',
 'pQ6_SERPINA5',
 'pQ7_C1QA',
 'pQ7_GSTA1',
 'pQ8_CPN1'])

feats_list.append(['abQ_LV302',
 'pQ1_IGKC',
 'pQ1_SERPINC1',
 'pQ2_ITIH1',
 'pQ2_KLKB1',
 'pQ3_PROC_a',
 'pQ3_PROS1_a',
 'pQ3_VWF',
 'pQ5_FABP1',
 'pQ6_C1R',
 'pQ6_SERPINA5',
 'pQ7_ATRN',
 'pQ7_CST3',
 'pQ7_GSTA1',
 'pQ7_MPO',
 'pQ8_PAR2'])

feats_list.append(['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2','pQ7_PRG4'])

feats_list.append(['abQ_IGHA1_2',
 'abQ_IGHA2',
 'pQ2_HBA1',
 'pQ2_HBB',
 'pQ3_CA1',
 'pQ3_CRP_a',
 'pQ3_CRP_b',
 'pQ3_MB',
 'pQ4_FABP1',
 'pQ5_FABP1',
 'pQ5_SAA1_A2',
 'pQ7_CFD',
 'pQ7_CXCL7',
 'pQ7_GSTA1',
 'pQ7_PLF4',
 'pQ7_THBD',
 'pQ8_PLAT',
 'cn_ly30'])

feats_list.append(['pQ2_APOE',
 'pQ3_PROC_b',
 'pQ5_SERPINF2',
 'pQ6_C8B',
 'pQ6_SERPINA10',
 'pQ6_SERPINA5',
 'pQ8_PAR2'])
unique_values = set()
for sublist in feats_list:
    for value in sublist:
        unique_values.add(value)

univals = list(unique_values)

feature_selectors = ['chi2','mutual_info_classif','SelectFromModel','BorutaShapSelected','VarianceThreshold', 'RecursiveElimination']

# %%
learning_rate = [float(x) for x in np.linspace(0.00001, 2.5, num = 10)]
booster = ['gbtree', 'gblinear', 'dart']
gamma = [float(x) for x in np.linspace(0.00001, 2.0, num = 10)]
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 250, num = 10)]
algorithm = ['SAMME', 'SAMME.R']
C = [float(x) for x in np.linspace(0.00001, 2.0, num = 10)]
kernel = ['poly', 'rbf', 'sigmoid']
max_iter = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
penalty = ['l1', 'l2', 'elasticnet', 'none']
# Number of features to consider at every split
criterion = ['gini', 'entropy', 'log_loss']
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(2, 200, num = 10)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
hidden_layer_sizes = [int(x) for x in np.linspace(start = 2, stop = 100, num = 10)]
activation =  ['identity', 'logistic', 'relu']
alpha = [float(x) for x in np.linspace(0.00001, .5, num = 10)]

random_grid = [ 
    {'learning_rate': learning_rate, 'booster':booster, 'gamma':gamma},
    {'n_estimators': n_estimators, 'learning_rate':learning_rate,'algorithm':algorithm},
    {'C': C, 'kernel': kernel, 'max_iter': max_iter},
    {'C': C, 'penalty': penalty},
    {'n_estimators': n_estimators,'criterion': criterion, 'max_depth': max_depth},
    {'hidden_layer_sizes': hidden_layer_sizes, 'activation': activation, 'alpha': alpha},
    ]

# %% [markdown]
# gs = rfxgb_clf_random.fit(X_train, y_train)
# print(gs.best_score_)
# print(gs.best_params_)
#
# clf = gs.best_estimator_
# print('Test accuracy: %.3f' % clf.score(X_test, y_test))
# pred = clf.predict(X_test)
# score = accuracy_score(y_test, pred)
# cm = confusion_matrix(y_test, pred)
# cr = classification_report(y_test, pred)
#
# print("-"*90)
# print("Accuracy Score: {} With Classifier: {}".format(score, clf))
# print("-"*90)
# print("printing classification report to console along with dataset and dataset number: ")
# print("-"*90)
# print("CLASS_REPORT: {}".format(cr))
# print("-"*90)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier


accuracy_scoreDict = {'Classifiers': [], "BestScore": [], "BestEstimator" : [], 'Accuracy Score':[]}

Parameters_df = pd.DataFrame(columns=['Classifier', 'Parameters'])

names = [
    "XGB",
    "ADABoost"
    "SVC",
    "LogReg",    
    "Random Forest",
    "Neural Net",
]

classifiers = [
    XGBClassifier(random_state=42),
    AdaBoostClassifier(random_state=42),
    SVC(random_state=1),
    LogisticRegression(random_state=1),
    RandomForestClassifier(random_state=1),
    MLPClassifier(random_state=1),
]


param_grid = [ 
    {'learning_rate': [0.001, 0.01, .1], 'booster':['gbtree', 'gblinear', 'dart'], 'gamma':[0.5, 1.0, 1.5]},
    {'n_estimators': [25, 75, 110], 'learning_rate':[0.5, 1.0, 1.5],'algorithm':['SAMME', 'SAMME.R']},
    {'C': [0.5, 1.0, 1.5], 'kernel': ['poly', 'rbf', 'sigmoid'], 'max_iter':[500, 1250, 2000]},
    {'C': [0.5, 1.0, 1.5], 'penalty': ['l1', 'l2', 'elasticnet', 'none']},
    {'n_estimators': [50, 125, 250],'criterion': ['gini', 'entropy', 'log_loss'], 'max_depth': [None, 5, 20]},
    {'hidden_layer_sizes': [50, 100, 125], 'activation': ['identity', 'logistic', 'relu'], 'alpha': [.0001, .001, .01]},
    ]


  

for classifiers, random_grid in zip(classifiers, random_grid):
    grid_search = GridSearchCV(classifiers, cv=5,param_grid=random_grid , scoring='accuracy', return_train_score=True)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11, test_size=.20)

  
    grid_search.fit(X_train, y_train)
    pred = grid_search.predict(X_test)
    score = accuracy_score(y_test, pred) 
    cm = confusion_matrix(y_test, pred)
    cr = classification_report(y_test, pred)

    #score = grid_search.score(X_test, y_test)
    #print("Test Score: {} With Classifier: {}".format(score, clf))
    # Get the classifier's parameters
    params = classifiers.get_params()
    # Add the classifier name and parameters to the dataframe
    Parameters_df = Parameters_df.append({'Classifier': classifiers.__class__.__name__, 'Parameters': params}, ignore_index=True)

    accuracy_scoreDict['Accuracy Score'].append(score)
    
    #accuracy_scoreDict['Accuracy Score'].append(score) 
    accuracy_scoreDict['Classifiers'].append(classifiers.__class__.__name__)
    accuracy_scoreDict['BestScore'].append(grid_search.best_score_)
    accuracy_scoreDict['BestEstimator'].append(grid_search.best_estimator_)
    print("-"*90)
    print("Accuracy Score: {} With Classifier: {}".format(score, classifiers))
    print("-"*90)
    print(f"Best hyperparameters for {classifiers.__class__.__name__}: {grid_search.best_params_}")
    print(f"Best score for {classifiers.__class__.__name__}: {grid_search.best_score_:.3f}")
    print("-"*90)

          

accuracy_score_df = pd.DataFrame(accuracy_scoreDict)

accuracy_score_df['Parameters'] = Parameters_df.Parameters
# Out:
# ------------------------------------------------------------------------------------------
# Accuracy Score: 0.8181818181818182 With Classifier: XGBClassifier(random_state=42)
# ------------------------------------------------------------------------------------------
# Best hyperparameters for XGBClassifier: {'booster': 'gbtree', 'gamma': 2.0, 'learning_rate': 0.83334}
# Best score for XGBClassifier: 0.883
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Accuracy Score: 0.9090909090909091 With Classifier: AdaBoostClassifier(random_state=42)
# ------------------------------------------------------------------------------------------
# Best hyperparameters for AdaBoostClassifier: {'algorithm': 'SAMME', 'learning_rate': 1.66667, 'n_estimators': 170}
# Best score for AdaBoostClassifier: 0.908
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Accuracy Score: 0.7272727272727273 With Classifier: SVC(random_state=1)
# ------------------------------------------------------------------------------------------
# Best hyperparameters for SVC: {'C': 0.8888944444444443, 'kernel': 'poly', 'max_iter': 200}
# Best score for SVC: 0.978
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Accuracy Score: 0.6363636363636364 With Classifier: LogisticRegression(random_state=1)
# ------------------------------------------------------------------------------------------
# Best hyperparameters for LogisticRegression: {'C': 1.7777788888888888, 'penalty': 'l2'}
# Best score for LogisticRegression: 0.953
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Accuracy Score: 0.8181818181818182 With Classifier: RandomForestClassifier(random_state=1)
# ------------------------------------------------------------------------------------------
# Best hyperparameters for RandomForestClassifier: {'criterion': 'gini', 'max_depth': 24, 'n_estimators': 143}
# Best score for RandomForestClassifier: 0.906
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Accuracy Score: 0.6363636363636364 With Classifier: MLPClassifier(random_state=1)
# ------------------------------------------------------------------------------------------
# Best hyperparameters for MLPClassifier: {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': 67}
# Best score for MLPClassifier: 0.881
# ------------------------------------------------------------------------------------------

# %%
accuracy_score_df
# Out:
#               Classifiers  BestScore  \
# 0           XGBClassifier   0.883333
# 1      AdaBoostClassifier   0.908333
# 2                     SVC   0.977778
# 3      LogisticRegression   0.952778
# 4  RandomForestClassifier   0.905556
# 5           MLPClassifier   0.880556
#
#                                        BestEstimator  Accuracy Score  \
# 0  XGBClassifier(gamma=2.0, learning_rate=0.83334...        0.818182
# 1  (DecisionTreeClassifier(max_depth=1, random_st...        0.909091
# 2  SVC(C=0.8888944444444443, kernel='poly', max_i...        0.727273
# 3  LogisticRegression(C=1.7777788888888888, rando...        0.636364
# 4  (DecisionTreeClassifier(max_depth=24, max_feat...        0.818182
# 5  MLPClassifier(activation='logistic', alpha=1e-...        0.636364
#
#                                           Parameters
# 0  {'base_score': 0.5, 'booster': 'gbtree', 'cols...
# 1  {'algorithm': 'SAMME.R', 'base_estimator': Non...
# 2  {'C': 1.0, 'break_ties': False, 'cache_size': ...
# 3  {'C': 1.0, 'class_weight': None, 'dual': False...
# 4  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 5  {'activation': 'relu', 'alpha': 0.0001, 'batch...

# %%
names = [
    "XGB",
    "ADABoost"
    "SVC",
    "LogReg",    
    "Random Forest",
    "Neural Net",
]

bestcls = [
    XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01, random_state=42),
    AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75, random_state=42)	,
    SVC(kernel='sigmoid', max_iter=500, random_state=1),
    LogisticRegression(C=0.5, penalty='none', random_state=1),
    RandomForestClassifier(n_estimators=125, random_state=1),	
    MLPClassifier(activation='logistic', hidden_layer_sizes=100, random_state=1),	
]

# %%
from sklearn.model_selection import RandomizedSearchCV

from pprint import pprint


learning_rate = [float(x) for x in np.linspace(0.00001, 2.5, num = 10)]
booster = ['gbtree', 'gblinear', 'dart']
gamma = [float(x) for x in np.linspace(0.00001, 2.0, num = 10)]
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 250, num = 10)]
algorithm = ['SAMME', 'SAMME.R']
C = [float(x) for x in np.linspace(0.00001, 2.0, num = 10)]
kernel = ['poly', 'rbf', 'sigmoid']
max_iter = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
penalty = ['l1', 'l2', 'elasticnet', 'none']
# Number of features to consider at every split
criterion = ['gini', 'entropy', 'log_loss']
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(2, 200, num = 10)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
hidden_layer_sizes = [int(x) for x in np.linspace(start = 2, stop = 200, num = 10)]
activation =  ['identity', 'logistic', 'relu']
alpha = [float(x) for x in np.linspace(0.00001, .5, num = 10)]

Rand_SearchCVresults = {'Classifiers': [], 'Params': [], "BestScore": []}


classifiers = [
    XGBClassifier(random_state=42),
    AdaBoostClassifier(random_state=42),
    SVC(random_state=1),
    LogisticRegression(random_state=1),
    RandomForestClassifier(random_state=1),
    MLPClassifier(random_state=1),
]


random_grid = [ 
    {'learning_rate': learning_rate, 'booster':booster, 'gamma':gamma},
    {'n_estimators': n_estimators, 'learning_rate':learning_rate,'algorithm':algorithm},
    {'C': C, 'kernel': kernel, 'max_iter': max_iter},
    {'C': C, 'penalty': penalty},
    {'n_estimators': n_estimators,'criterion': criterion, 'max_depth': max_depth},
    {'hidden_layer_sizes': hidden_layer_sizes, 'activation': activation, 'alpha': alpha},
    ]

for classifiers, random_grid in zip(classifiers, random_grid):
    rand_search = RandomizedSearchCV(classifiers, cv=5,param_distributions=random_grid , scoring='accuracy', return_train_score=True,random_state=12)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11, test_size=.20)

    rand_search.fit(X_train, y_train)
    Rand_SearchCVresults['Classifiers'].append(classifiers.__class__.__name__)
    Rand_SearchCVresults['Params'].append(rand_search.best_params_)
    Rand_SearchCVresults['BestScore'].append(rand_search.best_score_)
    #Rand_SearchCVresults['BestEstimator'].append(rand_search.best_estimator_)
    print(f"Best hyperparameters for {classifiers.__class__.__name__}: {rand_search.best_params_}")
    print(f"Best score for {classifiers.__class__.__name__}: {rand_search.best_score_:.3f}")

Rand_SearchCVresultsdf = pd.DataFrame(Rand_SearchCVresults)
# Out:
# Best hyperparameters for XGBClassifier: {'learning_rate': 0.2777866666666667, 'gamma': 1.7777788888888888, 'booster': 'dart'}
# Best score for XGBClassifier: 0.861
# Best hyperparameters for AdaBoostClassifier: {'n_estimators': 90, 'learning_rate': 1.66667, 'algorithm': 'SAMME'}
# Best score for AdaBoostClassifier: 0.858
# Best hyperparameters for SVC: {'max_iter': 800, 'kernel': 'poly', 'C': 1.5555577777777776}
# Best score for SVC: 0.978
# Best hyperparameters for LogisticRegression: {'penalty': 'l2', 'C': 1.5555577777777776}
# Best score for LogisticRegression: 0.928
# Best hyperparameters for RandomForestClassifier: {'n_estimators': 196, 'max_depth': 134, 'criterion': 'gini'}
# Best score for RandomForestClassifier: 0.881
# Best hyperparameters for MLPClassifier: {'hidden_layer_sizes': 68, 'alpha': 0.055564444444444444, 'activation': 'relu'}
# Best score for MLPClassifier: 0.858

# %%
Rand_SearchCVresultsdf
# Out:
#               Classifiers                                             Params  \
# 0           XGBClassifier  {'learning_rate': 0.2777866666666667, 'gamma':...
# 1      AdaBoostClassifier  {'n_estimators': 90, 'learning_rate': 1.66667,...
# 2                     SVC  {'max_iter': 800, 'kernel': 'poly', 'C': 1.555...
# 3      LogisticRegression         {'penalty': 'l2', 'C': 1.5555577777777776}
# 4  RandomForestClassifier  {'n_estimators': 196, 'max_depth': 134, 'crite...
# 5           MLPClassifier  {'hidden_layer_sizes': 68, 'alpha': 0.05556444...
#
#    BestScore
# 0   0.861111
# 1   0.858333
# 2   0.977778
# 3   0.927778
# 4   0.880556
# 5   0.858333

# %%
names = [
    "XGB",
    "ADABoost"
    "SVC",
    "LogReg",    
    "Random Forest",
    "Neural Net",
]

bestclsFromRand = [
    XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001, random_state=42),
    AdaBoostClassifier(algorithm='SAMME.R', learning_rate=1.125025, n_estimators=98, random_state=42)	,
    SVC(C=1.5, kernel='poly', max_iter=987, random_state=1),
    LogisticRegression(C=0.75005, penalty='l2', random_state=1),
    RandomForestClassifier(n_estimators=125, max_depth = 60, criterion= 'gini', random_state=1),	
    MLPClassifier(activation='logistic', hidden_layer_sizes=125,  alpha=0.07502500000000001, random_state=1),	
]

# %%
feature_selectors = ['chi2','mutual_info_classif','SelectFromModel','BorutaShapSelected','VarianceThreshold', 'RecursiveElimination']

BestClsresults = {'Classifier': [],"Accuracy Score": [], 'Datasetfrom':[]}


names = [
    "XGB",
    "ADABoost"
    "SVC",
    "LogReg",    
    "Random Forest",
    "Neural Net"]

bestcls = [
    XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01, random_state=42),
    AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75, random_state=42)	,
    SVC(kernel='sigmoid', max_iter=500, random_state=1),
    LogisticRegression(C=0.5, penalty='none', random_state=1),
    RandomForestClassifier(n_estimators=125, random_state=1),	
    MLPClassifier(activation='logistic', hidden_layer_sizes=100, random_state=1)
    ]

concatfeats = list(unique_values)
for ds_cnt, ds in zip(feature_selectors,feats_list):
  X, y = X_to_drop[ds], y
  X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11, test_size=.20)

  for clf, name in zip(bestcls, names):
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    score = accuracy_score(y_test, pred) 
    cm = confusion_matrix(y_test, pred)
    cr = classification_report(y_test, pred)

    BestClsresults['Classifier'].append(name)
    BestClsresults['Accuracy Score'].append(score)
    BestClsresults['Datasetfrom'].append(ds_cnt)
    

    print("-"*90)
    print("Test Score: {} With Classifier: {}".format(score, clf))
    print("-"*90)
    print("printing classification report to console along with dataset and dataset number: ")
    print("{} : {}".format(ds, ds_cnt))

    print("-"*90)
    print("CLASS_REPORT: {}".format(cr))
    print("-"*90) 

performance_df = pd.DataFrame(BestClsresults)
# Out:
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.6363636363636364 With Classifier: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75,
#                    random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.80      0.57      0.67         7
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.66      0.63        11
# weighted avg       0.69      0.64      0.64        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: SVC(kernel='sigmoid', max_iter=500, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.8181818181818182 With Classifier: LogisticRegression(C=0.5, penalty='none', random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.86      0.86      0.86         7
#
#     accuracy                           0.82        11
#    macro avg       0.80      0.80      0.80        11
# weighted avg       0.82      0.82      0.82        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.6363636363636364 With Classifier: RandomForestClassifier(n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.80      0.57      0.67         7
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.66      0.63        11
# weighted avg       0.69      0.64      0.64        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75,
#                    random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         4
#            1       0.75      0.86      0.80         7
#
#     accuracy                           0.73        11
#    macro avg       0.71      0.68      0.69        11
# weighted avg       0.72      0.73      0.72        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: SVC(kernel='sigmoid', max_iter=500, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.45454545454545453 With Classifier: LogisticRegression(C=0.5, penalty='none', random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.25      0.25      0.25         4
#            1       0.57      0.57      0.57         7
#
#     accuracy                           0.45        11
#    macro avg       0.41      0.41      0.41        11
# weighted avg       0.45      0.45      0.45        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: RandomForestClassifier(n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         4
#            1       0.62      0.71      0.67         7
#
#     accuracy                           0.55        11
#    macro avg       0.48      0.48      0.48        11
# weighted avg       0.52      0.55      0.53        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75,
#                    random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         4
#            1       0.83      0.71      0.77         7
#
#     accuracy                           0.73        11
#    macro avg       0.72      0.73      0.72        11
# weighted avg       0.75      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: SVC(kernel='sigmoid', max_iter=500, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: LogisticRegression(C=0.5, penalty='none', random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.75      0.43      0.55         7
#
#     accuracy                           0.55        11
#    macro avg       0.59      0.59      0.55        11
# weighted avg       0.63      0.55      0.55        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.8181818181818182 With Classifier: RandomForestClassifier(n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         4
#            1       1.00      0.71      0.83         7
#
#     accuracy                           0.82        11
#    macro avg       0.83      0.86      0.82        11
# weighted avg       0.88      0.82      0.82        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75,
#                    random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         4
#            1       0.83      0.71      0.77         7
#
#     accuracy                           0.73        11
#    macro avg       0.72      0.73      0.72        11
# weighted avg       0.75      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: SVC(kernel='sigmoid', max_iter=500, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: LogisticRegression(C=0.5, penalty='none', random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         4
#            1       0.83      0.71      0.77         7
#
#     accuracy                           0.73        11
#    macro avg       0.72      0.73      0.72        11
# weighted avg       0.75      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: RandomForestClassifier(n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75,
#                    random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.20      0.25      0.22         4
#            1       0.50      0.43      0.46         7
#
#     accuracy                           0.36        11
#    macro avg       0.35      0.34      0.34        11
# weighted avg       0.39      0.36      0.37        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: SVC(kernel='sigmoid', max_iter=500, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.45454545454545453 With Classifier: LogisticRegression(C=0.5, penalty='none', random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.25      0.25      0.25         4
#            1       0.57      0.57      0.57         7
#
#     accuracy                           0.45        11
#    macro avg       0.41      0.41      0.41        11
# weighted avg       0.45      0.45      0.45        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.45454545454545453 With Classifier: RandomForestClassifier(n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.25      0.25      0.25         4
#            1       0.57      0.57      0.57         7
#
#     accuracy                           0.45        11
#    macro avg       0.41      0.41      0.41        11
# weighted avg       0.45      0.45      0.45        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.9090909090909091 With Classifier: AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75,
#                    random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       1.00      0.86      0.92         7
#
#     accuracy                           0.91        11
#    macro avg       0.90      0.93      0.91        11
# weighted avg       0.93      0.91      0.91        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: SVC(kernel='sigmoid', max_iter=500, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.36      1.00      0.53         4
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.36        11
#    macro avg       0.18      0.50      0.27        11
# weighted avg       0.13      0.36      0.19        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: LogisticRegression(C=0.5, penalty='none', random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.8181818181818182 With Classifier: RandomForestClassifier(n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         4
#            1       1.00      0.71      0.83         7
#
#     accuracy                           0.82        11
#    macro avg       0.83      0.86      0.82        11
# weighted avg       0.88      0.82      0.82        11
#
# ------------------------------------------------------------------------------------------

# %%
performance_df
# Out:
#        Classifier  Accuracy Score           Datasetfrom
# 0             XGB        0.363636                  chi2
# 1     ADABoostSVC        0.636364                  chi2
# 2          LogReg        0.363636                  chi2
# 3   Random Forest        0.818182                  chi2
# 4      Neural Net        0.636364                  chi2
# 5             XGB        0.363636   mutual_info_classif
# 6     ADABoostSVC        0.727273   mutual_info_classif
# 7          LogReg        0.363636   mutual_info_classif
# 8   Random Forest        0.454545   mutual_info_classif
# 9      Neural Net        0.545455   mutual_info_classif
# 10            XGB        0.363636       SelectFromModel
# 11    ADABoostSVC        0.727273       SelectFromModel
# 12         LogReg        0.363636       SelectFromModel
# 13  Random Forest        0.545455       SelectFromModel
# 14     Neural Net        0.818182       SelectFromModel
# 15            XGB        0.363636    BorutaShapSelected
# 16    ADABoostSVC        0.727273    BorutaShapSelected
# 17         LogReg        0.363636    BorutaShapSelected
# 18  Random Forest        0.727273    BorutaShapSelected
# 19     Neural Net        0.727273    BorutaShapSelected
# 20            XGB        0.363636     VarianceThreshold
# 21    ADABoostSVC        0.363636     VarianceThreshold
# 22         LogReg        0.363636     VarianceThreshold
# 23  Random Forest        0.454545     VarianceThreshold
# 24     Neural Net        0.454545     VarianceThreshold
# 25            XGB        0.363636  RecursiveElimination
# 26    ADABoostSVC        0.909091  RecursiveElimination
# 27         LogReg        0.363636  RecursiveElimination
# 28  Random Forest        0.727273  RecursiveElimination
# 29     Neural Net        0.818182  RecursiveElimination

# %%
feature_selectors = ['chi2','mutual_info_classif','SelectFromModel','BorutaShapSelected','VarianceThreshold', 'RecursiveElimination']

BestRandresults = {'Classifier': [],"Accuracy Score": [], 'Datasetfrom':[]}


names = [
    "XGB",
    "ADABoost"
    "SVC",
    "LogReg",    
    "Random Forest",
    "Neural Net",
]

bestclsFromRand = [
    XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001, random_state=42),
    AdaBoostClassifier(algorithm='SAMME.R', learning_rate=1.125025, n_estimators=98, random_state=42)	,
    SVC(C=1.5, kernel='poly', max_iter=987, random_state=1),
    LogisticRegression(C=0.75005, penalty='l2', random_state=1),
    RandomForestClassifier(n_estimators=125, max_depth = 60, criterion= 'gini', random_state=1),	
    MLPClassifier(activation='logistic', hidden_layer_sizes=125,  alpha=0.07502500000000001, random_state=1),	
]

concatfeats = list(unique_values)
for ds_cnt, ds in zip(feature_selectors,feats_list):
  X, y = X_to_drop[ds], y
  X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11, test_size=.20)

  for clf, name in zip(bestclsFromRand, names):
    clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    score = accuracy_score(y_test, pred) 
    cm = confusion_matrix(y_test, pred)
    cr = classification_report(y_test, pred)

    BestRandresults['Classifier'].append(name)
    BestRandresults['Accuracy Score'].append(score)
    BestRandresults['Datasetfrom'].append(ds_cnt)
    

    print("-"*90)
    print("Test Score: {} With Classifier: {}".format(score, clf))
    print("-"*90)
    print("printing classification report to console along with dataset and dataset number: ")
    print("{} : {}".format(ds, ds_cnt))

    print("-"*90)
    print("CLASS_REPORT: {}".format(cr))
    print("-"*90) 

Randperformance_df = pd.DataFrame(BestRandresults)
# Out:
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.75      0.43      0.55         7
#
#     accuracy                           0.55        11
#    macro avg       0.59      0.59      0.55        11
# weighted avg       0.63      0.55      0.55        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: AdaBoostClassifier(learning_rate=1.125025, n_estimators=98, random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.55         4
#            1       0.75      0.43      0.55         7
#
#     accuracy                           0.55        11
#    macro avg       0.59      0.59      0.55        11
# weighted avg       0.63      0.55      0.55        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: SVC(C=1.5, kernel='poly', max_iter=987, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         4
#            1       0.83      0.71      0.77         7
#
#     accuracy                           0.73        11
#    macro avg       0.72      0.73      0.72        11
# weighted avg       0.75      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.6363636363636364 With Classifier: LogisticRegression(C=0.75005, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.80      0.57      0.67         7
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.66      0.63        11
# weighted avg       0.69      0.64      0.64        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.6363636363636364 With Classifier: RandomForestClassifier(max_depth=60, n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHG1', 'pQ1_SERPINC1', 'pQ2_KLKB1', 'pQ2_SERPINF2_a', 'pQ2_SERPINF2_b', 'pQ5_SERPINF2', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_ATRN'] : chi2
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.80      0.57      0.67         7
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.66      0.63        11
# weighted avg       0.69      0.64      0.64        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.45454545454545453 With Classifier: XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.56      0.71      0.63         7
#
#     accuracy                           0.45        11
#    macro avg       0.28      0.36      0.31        11
# weighted avg       0.35      0.45      0.40        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.6363636363636364 With Classifier: AdaBoostClassifier(learning_rate=1.125025, n_estimators=98, random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.50      0.25      0.33         4
#            1       0.67      0.86      0.75         7
#
#     accuracy                           0.64        11
#    macro avg       0.58      0.55      0.54        11
# weighted avg       0.61      0.64      0.60        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.45454545454545453 With Classifier: SVC(C=1.5, kernel='poly', max_iter=987, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.56      0.71      0.63         7
#
#     accuracy                           0.45        11
#    macro avg       0.28      0.36      0.31        11
# weighted avg       0.35      0.45      0.40        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: LogisticRegression(C=0.75005, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.20      0.25      0.22         4
#            1       0.50      0.43      0.46         7
#
#     accuracy                           0.36        11
#    macro avg       0.35      0.34      0.34        11
# weighted avg       0.39      0.36      0.37        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: RandomForestClassifier(max_depth=60, n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGJ', 'pQ1_APOC1', 'pQ2_APOE', 'pQ2_F2_a', 'pQ3_CPB2', 'pQ5_A2M', 'pQ5_CFB', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_LGALS3BP', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ7_C1QA', 'pQ7_GSTA1', 'pQ8_CPN1'] : mutual_info_classif
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         4
#            1       0.62      0.71      0.67         7
#
#     accuracy                           0.55        11
#    macro avg       0.48      0.48      0.48        11
# weighted avg       0.52      0.55      0.53        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.6363636363636364 With Classifier: AdaBoostClassifier(learning_rate=1.125025, n_estimators=98, random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.80      0.57      0.67         7
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.66      0.63        11
# weighted avg       0.69      0.64      0.64        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: SVC(C=1.5, kernel='poly', max_iter=987, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.62         4
#            1       1.00      0.29      0.44         7
#
#     accuracy                           0.55        11
#    macro avg       0.72      0.64      0.53        11
# weighted avg       0.80      0.55      0.51        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: LogisticRegression(C=0.75005, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.44      1.00      0.62         4
#            1       1.00      0.29      0.44         7
#
#     accuracy                           0.55        11
#    macro avg       0.72      0.64      0.53        11
# weighted avg       0.80      0.55      0.51        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.8181818181818182 With Classifier: RandomForestClassifier(max_depth=60, n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_LV302', 'pQ1_IGKC', 'pQ1_SERPINC1', 'pQ2_ITIH1', 'pQ2_KLKB1', 'pQ3_PROC_a', 'pQ3_PROS1_a', 'pQ3_VWF', 'pQ5_FABP1', 'pQ6_C1R', 'pQ6_SERPINA5', 'pQ7_ATRN', 'pQ7_CST3', 'pQ7_GSTA1', 'pQ7_MPO', 'pQ8_PAR2'] : SelectFromModel
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         4
#            1       1.00      0.71      0.83         7
#
#     accuracy                           0.82        11
#    macro avg       0.83      0.86      0.82        11
# weighted avg       0.88      0.82      0.82        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.8181818181818182 With Classifier: AdaBoostClassifier(learning_rate=1.125025, n_estimators=98, random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         4
#            1       1.00      0.71      0.83         7
#
#     accuracy                           0.82        11
#    macro avg       0.83      0.86      0.82        11
# weighted avg       0.88      0.82      0.82        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.6363636363636364 With Classifier: SVC(C=1.5, kernel='poly', max_iter=987, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.50      0.75      0.60         4
#            1       0.80      0.57      0.67         7
#
#     accuracy                           0.64        11
#    macro avg       0.65      0.66      0.63        11
# weighted avg       0.69      0.64      0.64        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: LogisticRegression(C=0.75005, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: RandomForestClassifier(max_depth=60, n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ6_SERPINA10', 'pQ2_SERPINF2_a', 'pQ7_ATRN', 'pQ8_PAR2', 'pQ7_CPB2', 'pQ7_PRG4'] : BorutaShapSelected
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.45454545454545453 With Classifier: XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.38      0.75      0.50         4
#            1       0.67      0.29      0.40         7
#
#     accuracy                           0.45        11
#    macro avg       0.52      0.52      0.45        11
# weighted avg       0.56      0.45      0.44        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.5454545454545454 With Classifier: AdaBoostClassifier(learning_rate=1.125025, n_estimators=98, random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29         4
#            1       0.62      0.71      0.67         7
#
#     accuracy                           0.55        11
#    macro avg       0.48      0.48      0.48        11
# weighted avg       0.52      0.55      0.53        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.2727272727272727 With Classifier: SVC(C=1.5, kernel='poly', max_iter=987, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.43      0.43      0.43         7
#
#     accuracy                           0.27        11
#    macro avg       0.21      0.21      0.21        11
# weighted avg       0.27      0.27      0.27        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.36363636363636365 With Classifier: LogisticRegression(C=0.75005, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         4
#            1       0.50      0.57      0.53         7
#
#     accuracy                           0.36        11
#    macro avg       0.25      0.29      0.27        11
# weighted avg       0.32      0.36      0.34        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.45454545454545453 With Classifier: RandomForestClassifier(max_depth=60, n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['abQ_IGHA1_2', 'abQ_IGHA2', 'pQ2_HBA1', 'pQ2_HBB', 'pQ3_CA1', 'pQ3_CRP_a', 'pQ3_CRP_b', 'pQ3_MB', 'pQ4_FABP1', 'pQ5_FABP1', 'pQ5_SAA1_A2', 'pQ7_CFD', 'pQ7_CXCL7', 'pQ7_GSTA1', 'pQ7_PLF4', 'pQ7_THBD', 'pQ8_PLAT', 'cn_ly30'] : VarianceThreshold
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.25      0.25      0.25         4
#            1       0.57      0.57      0.57         7
#
#     accuracy                           0.45        11
#    macro avg       0.41      0.41      0.41        11
# weighted avg       0.45      0.45      0.45        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: XGBClassifier(booster='dart', gamma=0.0001, learning_rate=0.0001,
#               random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: AdaBoostClassifier(learning_rate=1.125025, n_estimators=98, random_state=42)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: SVC(C=1.5, kernel='poly', max_iter=987, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.7272727272727273 With Classifier: LogisticRegression(C=0.75005, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.73         4
#            1       1.00      0.57      0.73         7
#
#     accuracy                           0.73        11
#    macro avg       0.79      0.79      0.73        11
# weighted avg       0.84      0.73      0.73        11
#
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Test Score: 0.8181818181818182 With Classifier: RandomForestClassifier(max_depth=60, n_estimators=125, random_state=1)
# ------------------------------------------------------------------------------------------
# printing classification report to console along with dataset and dataset number:
# ['pQ2_APOE', 'pQ3_PROC_b', 'pQ5_SERPINF2', 'pQ6_C8B', 'pQ6_SERPINA10', 'pQ6_SERPINA5', 'pQ8_PAR2'] : RecursiveElimination
# ------------------------------------------------------------------------------------------
# CLASS_REPORT:               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         4
#            1       1.00      0.71      0.83         7
#
#     accuracy                           0.82        11
#    macro avg       0.83      0.86      0.82        11
# weighted avg       0.88      0.82      0.82        11
#
# ------------------------------------------------------------------------------------------

# %%
Randperformance_df
# Out:
#        Classifier  Accuracy Score           Datasetfrom
# 0             XGB        0.545455                  chi2
# 1     ADABoostSVC        0.545455                  chi2
# 2          LogReg        0.727273                  chi2
# 3   Random Forest        0.636364                  chi2
# 4      Neural Net        0.636364                  chi2
# 5             XGB        0.454545   mutual_info_classif
# 6     ADABoostSVC        0.636364   mutual_info_classif
# 7          LogReg        0.454545   mutual_info_classif
# 8   Random Forest        0.363636   mutual_info_classif
# 9      Neural Net        0.545455   mutual_info_classif
# 10            XGB        0.727273       SelectFromModel
# 11    ADABoostSVC        0.636364       SelectFromModel
# 12         LogReg        0.545455       SelectFromModel
# 13  Random Forest        0.545455       SelectFromModel
# 14     Neural Net        0.818182       SelectFromModel
# 15            XGB        0.727273    BorutaShapSelected
# 16    ADABoostSVC        0.818182    BorutaShapSelected
# 17         LogReg        0.636364    BorutaShapSelected
# 18  Random Forest        0.727273    BorutaShapSelected
# 19     Neural Net        0.727273    BorutaShapSelected
# 20            XGB        0.454545     VarianceThreshold
# 21    ADABoostSVC        0.545455     VarianceThreshold
# 22         LogReg        0.272727     VarianceThreshold
# 23  Random Forest        0.363636     VarianceThreshold
# 24     Neural Net        0.454545     VarianceThreshold
# 25            XGB        0.727273  RecursiveElimination
# 26    ADABoostSVC        0.727273  RecursiveElimination
# 27         LogReg        0.727273  RecursiveElimination
# 28  Random Forest        0.727273  RecursiveElimination
# 29     Neural Net        0.818182  RecursiveElimination

# %%
from sklearn.model_selection import GridSearchCV
docs = {'Classifer':[], 'test_acc': [], 'test_prec_macro':[], 'test_rec_micro':[]}
svcclf = SVC(kernel='sigmoid', max_iter=500, random_state=1)
logregclf = LogisticRegression(C=0.5, penalty='none', random_state=1)
rf_clf = RandomForestClassifier(n_estimators=125, random_state=1)
mlpclf = MLPClassifier(activation='logistic', hidden_layer_sizes=100, random_state=1)
voting_clf = VotingClassifier(estimators=[('lr', logregclf), ('rf', rf_clf), ('svc', svcclf), ('mlp', mlpclf)], voting='hard')
scoring = {'acc': 'accuracy',
           'prec_macro': 'precision_macro',
           'rec_micro': 'recall_macro'}

  
for clf in (logregclf, rf_clf, svcclf, mlpclf, voting_clf):
  X_train, X_test, y_train, y_test = train_test_split(X_to_drop[univals], y, random_state=11, test_size=.20)

  scores = cross_validate(clf, X_train, y_train, scoring=scoring,
                         cv=10, return_train_score=True)
  scoreKeys = pd.DataFrame(scores)
  docs['Classifer'].append(clf.__class__.__name__)
  docs['test_acc'].append(scoreKeys.test_acc)
  docs['test_acc'].append(scoreKeys.test_acc)

  print("-"*90)
  print(f"Cross Validaion Metrics for {clf.__class__.__name__}:")
  print(scoreKeys[['test_acc','test_prec_macro','test_rec_micro']].mean())
  print("-"*90)
# Out:
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for LogisticRegression:
# test_acc           0.590000
# test_prec_macro    0.541667
# test_rec_micro     0.583333
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for RandomForestClassifier:
# test_acc           0.900000
# test_prec_macro    0.916667
# test_rec_micro     0.900000
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for SVC:
# test_acc           0.5350
# test_prec_macro    0.2675
# test_rec_micro     0.5000
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for MLPClassifier:
# test_acc           0.660000
# test_prec_macro    0.655000
# test_rec_micro     0.658333
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for VotingClassifier:
# test_acc           0.735
# test_prec_macro    0.705
# test_rec_micro     0.725
# dtype: float64
# ------------------------------------------------------------------------------------------

# %%
from sklearn.model_selection import GridSearchCV
rand_docs = {'Classifer':[], 'test_acc': [], 'test_prec_macro':[], 'test_rec_micro':[]}

XGB = XGBClassifier(booster='gblinear', gamma=0.5, learning_rate=0.01, random_state=42)
Ada = AdaBoostClassifier(algorithm='SAMME', learning_rate=1.5, n_estimators=75, random_state=42)	
Svc = SVC(kernel='sigmoid', max_iter=500, random_state=1)
Logreg = LogisticRegression(C=0.5, penalty='none', random_state=1)
Rf = RandomForestClassifier(n_estimators=125, random_state=1)
Mlp = MLPClassifier(activation='logistic', hidden_layer_sizes=100, random_state=1)

voting_clf = VotingClassifier(estimators=[('XGB', XGB), ('Ada', Ada), ('svc', Svc), ('Logreg', Logreg), ('Rf', Rf), ('Mlp', Mlp)], voting='hard')
scoring = {'acc': 'accuracy',
           'prec_macro': 'precision_macro',
           'rec_micro': 'recall_macro'}

  
for clf in (XGB, Ada, Svc, Logreg, Rf, Mlp, voting_clf):
  X_train, X_test, y_train, y_test = train_test_split(X_to_drop[univals], y, random_state=11, test_size=.20)

  rand_scores = cross_validate(clf, X_train, y_train, scoring=scoring,
                         cv=10, return_train_score=True)
  rand_scoreKeys = pd.DataFrame(rand_scores)
  rand_docs['Classifer'].append(clf.__class__.__name__)
  rand_docs['test_acc'].append(scoreKeys.test_acc)
  rand_docs['test_acc'].append(scoreKeys.test_acc)

  print("-"*90)
  print(f"Cross Validaion Metrics for {clf.__class__.__name__}:")
  print(rand_scoreKeys[['test_acc','test_prec_macro','test_rec_micro']].mean())
  print("-"*90)
# Out:
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for XGBClassifier:
# test_acc           0.5350
# test_prec_macro    0.3175
# test_rec_micro     0.5000
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for AdaBoostClassifier:
# test_acc           0.760000
# test_prec_macro    0.766667
# test_rec_micro     0.758333
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for SVC:
# test_acc           0.5350
# test_prec_macro    0.2675
# test_rec_micro     0.5000
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for LogisticRegression:
# test_acc           0.590000
# test_prec_macro    0.541667
# test_rec_micro     0.583333
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for RandomForestClassifier:
# test_acc           0.900000
# test_prec_macro    0.916667
# test_rec_micro     0.900000
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for MLPClassifier:
# test_acc           0.660000
# test_prec_macro    0.655000
# test_rec_micro     0.658333
# dtype: float64
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Cross Validaion Metrics for VotingClassifier:
# test_acc           0.710000
# test_prec_macro    0.646667
# test_rec_micro     0.700000
# dtype: float64
# ------------------------------------------------------------------------------------------

# %%
\
# Out:
#   File "<ipython-input-16-0938bd8906ef>", line 1
#     \
#      ^
# SyntaxError: unexpected EOF while parsing
